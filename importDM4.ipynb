# %%
import atomap.api as am
import matplotlib
import numpy as np
import atomap.dummy_data as dummy_data
import hyperspy.api as hs

# %%
your_image = hs.load("/Users/seyfal/Desktop/CVAE/ML_Local/data/images_3D/EELS HL SI.dm4") 
your_image.plot()

print(your_image.data.shape)
# Out:
# (51, 50, 1980)
