# %%
import atomap.api as am
import matplotlib
import numpy as np
import atomap.dummy_data as dummy_data

# %%
s = dummy_data.get_simple_cubic_signal(image_noise=True)
s.plot()

# %%
import hyperspy.api as hs

# %%
your_image = hs.load("EELS Spectrum Image (high-loss).dm4") 
your_image.plot()

print(your_image.data.shape)
# Out:
# (17, 13, 1914)

# %%
s_peaks = am.get_feature_separation(s, separation_range=(7, 20), show_progressbar=False)
s_peaks.plot()
