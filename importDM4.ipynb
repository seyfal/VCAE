# %%
import atomap.api as am
import matplotlib
import numpy as np
import atomap.dummy_data as dummy_data
import hyperspy.api as hs

# %%
your_image = hs.load("/Users/seyfal/Desktop/CVAE/ML_Local/data/images_3D/BFO_a-0090 (dark ref corrected).dm3") 

# plot the image and show the spectra of the middle pixel 
your_image.plot()

# %%
your_image_1 = hs.load("/Users/seyfal/Desktop/CVAE/ML_Local/data/images_3D/EELS HL SI.dm4") 

# plot the image and show the spectra of the middle pixel 
your_image_1.plot()
