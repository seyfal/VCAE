# %%
import matplotlib
import numpy as np
import hyperspy.api as hs

# %%
your_image = hs.load("/home/ssulta24/VCAE/data/images_3D/BFO_a-0090 (dark ref corrected).dm3") 

# plot the image and show the spectra of the middle pixel 
your_image.plot()

# what is the shape of this image 
print(your_image.data.shape)
# Out:
# (210, 210, 1340)

# %%
your_image_1 = hs.load("/Users/seyfal/Desktop/CVAE/ML_Local/data/images_3D/EELS HL SI.dm4") 

# plot the image and show the spectra of the middle pixel 
your_image_1.plot()
